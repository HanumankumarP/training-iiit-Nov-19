# %% [markdown]
# ### More on Pands

# %%
import pandas as pd
import numpy as np

# %%
g_df=pd.read_csv("market_fact.csv")

# %%
g_df
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id       Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818    136.8100      0.01
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818     42.2700      0.01
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818   4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818   2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818   4233.1500      0.08
# 5     Ord_5446   Prod_6  SHP_7608  Cust_1818    164.0200      0.03
# 6       Ord_31  Prod_12    SHP_41    Cust_26     14.7600      0.01
# 7     Ord_4725   Prod_4  SHP_6593  Cust_1641   3410.1575      0.10
# 8     Ord_4725  Prod_13  SHP_6593  Cust_1641    162.0000      0.01
# 9     Ord_4725   Prod_6  SHP_6593  Cust_1641     57.2200      0.07
# 10    Ord_4743   Prod_2  SHP_6615  Cust_1641   4072.0100      0.01
# 11    Ord_1925   Prod_6  SHP_2637   Cust_708    465.9000      0.05
# 12    Ord_2978  Prod_16  SHP_4112  Cust_1088    305.0500      0.04
# ...

# %%
g_df.shape
# Out:
# (8399, 10)

# %%
g_df.head(4)
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 0   -30.51           3.60                 0.56
# 1     4.56           0.93                 0.54
# 2  1148.90           2.50                 0.59
# 3   729.34          14.30                 0.37

# %%
g_df.tail(2)
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  \
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.87      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.69      0.00
#
#       Order_Quantity  Profit  Shipping_Cost  Product_Base_Margin
# 8397              23  565.34          30.00                 0.62
# 8398              47  131.39           4.86                 0.38

# %%
g_df.columns
# Out:
# Index(['Ord_id', 'Prod_id', 'Ship_id', 'Cust_id', 'Sales', 'Discount',
#        'Order_Quantity', 'Profit', 'Shipping_Cost', 'Product_Base_Margin'],
#       dtype='object')

# %%
g_df.sample(5)
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 8005  Ord_2222  Prod_16  SHP_6470  Cust_1602    88.2300      0.10
# 4227   Ord_472  Prod_15   SHP_634   Cust_171  3114.0500      0.01
# 226    Ord_628   Prod_4   SHP_860   Cust_220   477.5045      0.09
# 6401  Ord_1251   Prod_5  SHP_1728   Cust_469  8958.4600      0.02
# 1398  Ord_2494  Prod_13  SHP_3419   Cust_961    49.4900      0.01
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 8005              42  -195.93           5.00                 0.81
# 4227              32 -1207.18          74.35                 0.57
# 226               17  -245.56           5.00                 0.85
# 6401              41  2593.14          21.21                 0.59
# 1398              28    -1.23           0.70                 0.56

# %%
g_df.index
# Out:
# RangeIndex(start=0, stop=8399, step=1)

# %%
g_df.isnull().sum()
# g_df.isnull().sum().sum()
# Out:
# Ord_id                  0
# Prod_id                 0
# Ship_id                 0
# Cust_id                 0
# Sales                   0
# Discount                0
# Order_Quantity          0
# Profit                  0
# Shipping_Cost           0
# Product_Base_Margin    63
# dtype: int64

# %%
g_df.dtypes
# Out:
# Ord_id                  object
# Prod_id                 object
# Ship_id                 object
# Cust_id                 object
# Sales                  float64
# Discount               float64
# Order_Quantity           int64
# Profit                 float64
# Shipping_Cost          float64
# Product_Base_Margin    float64
# dtype: object

# %%
g=g_df.columns.to_series().groupby(g_df.dtypes).groups
g
# Out:
# {dtype('int64'): Index(['Order_Quantity'], dtype='object'),
#  dtype('float64'): Index(['Sales', 'Discount', 'Profit', 'Shipping_Cost', 'Product_Base_Margin'], dtype='object'),
#  dtype('O'): Index(['Ord_id', 'Prod_id', 'Ship_id', 'Cust_id'], dtype='object')}

# %%
# num_cols_Obj=g_df.columns[g_df.dtypes==object]
# num_cols_int=g_df.columns[(g_df.dtypes!=object)&(g_df.dtypes!=float)]
# num_cols_float=g_df.columns[g_df.dtypes==float]
# print("Object=>",len(num_cols_Obj))
# print("Integer=>",len(num_cols_int))
# print("Float=>",len(num_cols_float))
g_df.dtypes.value_counts()
# Out:
# float64    5
# object     4
# int64      1
# dtype: int64

# %%
num_cols_int=g_df.columns[g_df.dtypes==int]
num_cols_int
# Out:
# Index([], dtype='object')

# %%
g_df.columns
# Out:
# Index(['Ord_id', 'Prod_id', 'Ship_id', 'Cust_id', 'Sales', 'Discount',
#        'Order_Quantity', 'Profit', 'Shipping_Cost', 'Product_Base_Margin'],
#       dtype='object')

# %%
for col in g_df.columns:
    print(g_df[col].min(),g_df[col].max())
# Out:
# Ord_1 Ord_999
# Prod_1 Prod_9
# SHP_1 SHP_999
# Cust_1 Cust_999
# 2.24 89061.05
# 0.0 0.25
# 1 50
# -14140.7 27220.69
# 0.49 164.73
# 0.35 0.85

# %%
g_df.describe()
# Out:
#               Sales     Discount  Order_Quantity        Profit  Shipping_Cost  \
# count   8399.000000  8399.000000     8399.000000   8399.000000    8399.000000
# mean    1775.878179     0.049671       25.571735    181.184424      12.838557
# std     3585.050525     0.031823       14.481071   1196.653371      17.264052
# min        2.240000     0.000000        1.000000 -14140.700000       0.490000
# 25%      143.195000     0.020000       13.000000    -83.315000       3.300000
# 50%      449.420000     0.050000       26.000000     -1.500000       6.070000
# 75%     1709.320000     0.080000       38.000000    162.750000      13.990000
# max    89061.050000     0.250000       50.000000  27220.690000     164.730000
#
#        Product_Base_Margin
# count          8336.000000
# mean              0.512513
# std               0.135589
# min               0.350000
# 25%               0.380000
# 50%               0.520000
# 75%               0.590000
# max               0.850000

# %%
cat_cols=g_df.columns[g_df.dtypes==object]
cat_cols
# Out:
# Index(['Ord_id', 'Prod_id', 'Ship_id', 'Cust_id'], dtype='object')

# %%
g_df.nunique()
# Out:
# Ord_id                 5506
# Prod_id                  17
# Ship_id                7701
# Cust_id                1832
# Sales                  8153
# Discount                 16
# Order_Quantity           50
# Profit                 7807
# Shipping_Cost           652
# Product_Base_Margin      51
# dtype: int64

# %%
for i in cat_cols:
    print(g_df[i].value_counts())
# Out:
# Ord_542     6
# Ord_2506    6
# Ord_1053    5
# Ord_1581    5
# Ord_1664    5
# Ord_1791    5
# Ord_1234    5
# Ord_1931    5
# Ord_4025    5
# Ord_2164    5
# Ord_2970    5
# Ord_2370    5
# Ord_4946    5
# Ord_996     5
# Ord_1980    5
# Ord_2894    5
# Ord_845     5
# Ord_1639    5
# Ord_1846    5
# Ord_5186    5
# Ord_56      5
# Ord_3806    4
# Ord_303     4
# Ord_2853    4
# Ord_1699    4
# Ord_4757    4
# Ord_1736    4
# Ord_643     4
# Ord_3040    4
# Ord_4792    4
#            ..
# Ord_4097    1
# Ord_2443    1
# Ord_4420    1
# Ord_568     1
# Ord_3389    1
# Ord_138     1
# Ord_5053    1
# Ord_1144    1
# Ord_5173    1
# Ord_5237    1
# Ord_2912    1
# Ord_5453    1
# Ord_4775    1
# Ord_2179    1
# Ord_2640    1
# Ord_961     1
# Ord_2689    1
# Ord_4274    1
# Ord_2742    1
# Ord_3218    1
# Ord_3203    1
# Ord_3664    1
# Ord_205     1
# Ord_4362    1
# Ord_4082    1
# Ord_4358    1
# Ord_3949    1
# Ord_2669    1
# Ord_2602    1
# Ord_733     1
# ...

# %%
market_df=pd.read_csv("market_fact.csv")
cust_df=pd.read_csv("cust_dimen.csv")
order_df=pd.read_csv("orders_dimen.csv")
product_df=pd.read_csv("prod_dimen.csv")
product_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e6e931ebe05d> in <module>
# ----> 1 market_df=pd.read_csv("market_fact.csv")
#       2 cust_df=pd.read_csv("cust_dimen.csv")
#       3 order_df=pd.read_csv("orders_dimen.csv")
#       4 product_df=pd.read_csv("prod_dimen.csv")
#       5 product_df
#
# NameError: name 'pd' is not defined
